# %% [markdown]
# <a href="https://colab.research.google.com/github/durveshpathak1989/Prob_BootCamp/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

X = [12,24,56,10,1,202]
y = np.arange(0, 1.2, 0.2)

plt.plot(y,X)
